# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("GOOGLE_API_KEY")


print(f"Your API key is: {api_key}")

# %%
from google.genai import types

from google.adk.agents import LlmAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.sessions import InMemorySessionService
from google.adk.tools import google_search, AgentTool, ToolContext
from google.adk.code_executors import BuiltInCodeExecutor

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config = types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504],  # Retry on these HTTP errors
)

# %%
root_agent = Agent(
    name="Lana Biscornet Agent",
    model="gemini-2.5-flash-lite",
    description="An AI social and professional assistant for web dev Lana Biscornet.",
    instruction="Your job is to learn about Lana and communicate professionally on her behalf, answering questions and assisting with tasks as needed.",
    tools=[google_search],
)

print("✅ Root Agent defined.")
# Out:
# ✅ Root Agent defined.

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")
# Out:
# ✅ Runner created.

# %%
response = await runner.run_debug("What is Agent Development Kit from Google? What languages is the SDK available in?")
# Out:
#  ### Created new session: debug_session_id
#
# User > What is Agent Development Kit from Google? What languages is the SDK available in?
# helpful_assistant > The Google Agent Development Kit (ADK) is an open-source, flexible, and modular framework designed to simplify the development, deployment, and orchestration of AI agents and multi-agent systems. It aims to make agent development more akin to traditional software development, enabling developers to create complex agentic architectures. ADK is optimized for Gemini and the Google ecosystem but is designed to be model-agnostic and deployment-agnostic, allowing compatibility with other frameworks.
#
# The SDK is available in the following languages:
# *   Python
# *   Go
# *   Java

# %%
# !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY
# Out:
# Agent created in c:\Users\Owner\OneDrive\Desktop\Documents\AgentFlow\about_Lana_agent\sample-agent:
# - .env
# - __init__.py
# - agent.py

# %%
# !adk web --host 0.0.0.0 --port 8001
# Out:
# ^C
